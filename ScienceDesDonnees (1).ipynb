# %% [markdown]
# # Auteur
# **Nom : SOMLAN Marius**

# %% [markdown]
# # Exercice 2 - Titre du Carnet
#
# # Carnet de Science des Données
#
# ---
#
# # Exercice 3 - Introduction
#
# Ce carnet est une introduction à la science des données. Il contient des informations sur les langages, bibliothèques, outils, et des exemples pratiques pour effectuer des calculs simples. Ce projet est conçu pour les débutants.
#
# ---
#
# # Exercice 4 - Langages de la Science des Données
#
# - Python
# - R
# - Julia
# - SQL
# - MATLAB
# - Scala
#
# ---
#
# # Exercice 5 - Bibliothèques de Science des Données
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - PyTorch
#
# ---
#
# # Exercice 6 - Tableau des Outils de la Science des Données
#
# | Outil            | Description                          |
# |------------------|--------------------------------------|
# | Jupyter Notebook | Environnement interactif pour Python |
# | RStudio          | IDE pour R                          |
# | TensorBoard      | Visualisation de modèles TensorFlow |
# | Apache Spark     | Traitement distribué des données    |
# | Tableau          | Visualisation interactive des données|
#
# ---
#
# # Exercice 7 - Exemples d'Expressions Arithmétiques
#
# Quelques exemples d'expressions arithmétiques :
#
# - Addition : `3 + 5 = 8`
# - Multiplication : `4 * 7 = 28`
# - Division : `10 / 2 = 5`
# - Puissance : `2 ** 3 = 8`
#
# ---
#
# # Exercice 8 - Multiplication et Addition de Nombres
#
# ```python
# # Exécution d'une multiplication et d'une addition
# result = (5 * 4) + 3
# print("Le résultat est :", result)
# ```
#
# ---
#
# # Exercice 9 - Conversion des Minutes en Heures
#
# ```python
# # Conversion des minutes en heures
# minutes = 150
# heures = minutes / 60
# print(f"{minutes} minutes correspondent à {heures:.2f} heures.")
# ```
#
# ---
#
# # Exercice 10 - Objectifs
#
# Les objectifs de ce carnet sont :
#
# 1. Comprendre les bases de la science des données.
# 2. Découvrir les outils et bibliothèques essentiels.
# 3. Pratiquer des calculs simples avec Python.
#
# ---
#
# # Exercice 11 - Auteur
#
# **Nom : SOMLAN Marius**
#
# ---
#
# # Exercice 12 - Partager sur GitHub
